# %%
import numpy as np, pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pyteomics import mzxml
from featureDetection import detectFeatures

# %matplotlib inline
# Out:
# C:\Users\jcho\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
inputFile = "isotope_distribution.xlsx"
paramFile = "jumpm_targeted.params"
mzxmlFile = r"C:\Users\jcho\OneDrive - St. Jude Children's Research Hospital\UDrive\Research\Projects\7Metabolomics\Datasets\13Ctracer_rawdata\7_tracer.mzXML"

# Input dataframe (from Surendhar's program)
inputDf = pd.read_excel(inputFile)

# %%
features = detectFeatures(inputDf, mzxmlFile, paramFile)
# Out:
#   Feature detection from 7_tracer.mzXML
#   Progress: [####################] 100% Done...

# %%
features[(features["mz"] > 115) & (features["mz"] < 122) & (features["metabolite"] != -1)]
# Out:
#               mz     intensity    z       RT      minRT    maxRT      MS1  \
# 1027  115.002853  1.036955e+07  1.0  1665.72  1632.6100  2592.78   5090.0
# 1028  118.012970  4.312582e+05  1.0  1665.72  1658.8200  1676.08   5090.0
# 1029  116.006271  1.486938e+06  1.0  1666.38  1657.4000  1678.74   5092.0
# 1030  117.009628  1.862003e+06  1.0  1666.38  1657.4000  1679.07   5092.0
# 1031  117.009552  1.398725e+05  1.0  1762.22  1713.5600  1919.23   5421.0
# 1032  116.006096  1.343619e+05  1.0  1763.79  1712.8400  1929.53   5426.0
# 1082  117.018471  5.695574e+07  1.0  1698.21   301.7770  3664.70   5200.0
# 1083  118.021927  5.607302e+06  1.0  1698.21  1681.4700  1751.01   5200.0
# 1084  119.025322  5.910080e+06  1.0  1698.21  1687.6600  1721.09   5200.0
# 1085  120.028603  1.441508e+06  1.0  1698.21  1689.9500  1713.24   5200.0
# 1086  121.029739  1.352334e+05  1.0  2759.08  2758.1400  2760.94   8877.0
# 1087  121.029778  1.611474e+05  1.0  2781.52  2762.8800  2783.06   8954.0
# 1088  121.029778  1.681427e+05  1.0  2785.71  2784.7800  2790.58   8969.0
# 1089  121.029823  1.609710e+05  1.0  2793.13  2792.5100  2793.13   8996.0
# 1090  119.024323  2.246826e+05  1.0  2918.57  2793.1300  3083.79   9438.0
# 1091  121.028778  4.162916e+06  1.0  3196.89    60.1406  4800.27  10406.0
# 1092  117.018463  2.428050e+05  1.0  3724.24  3666.8000  4800.27  12084.0
#
#        minMS1   maxMS1      SNratio  PercentageTF metabolite
# 1027   4976.0   8305.0   598.156791     20.256198  HMDB00134
# 1028   5067.0   5125.0    24.876688      0.364125  HMDB00134
# 1029   5062.0   5133.0    95.052460      0.450199  HMDB00134
# 1030   5062.0   5134.0   119.028489      0.457161  HMDB00134
# 1031   5253.0   5965.0    11.567401      4.338911  HMDB00134
# 1032   5250.0   6002.0    10.500041      4.571394  HMDB00134
# 1082    770.0  11893.0  2632.416089     70.945806  HMDB00254
# 1083   5142.0   5381.0   259.161840      1.467049  HMDB00254
# 1084   5163.0   5279.0   273.155778      0.705255  HMDB00254
# 1085   5170.0   5252.0    66.624513      0.491337  HMDB00254
# 1086   8874.0   8883.0    10.347385      0.059070  HMDB00254
# 1087   8890.0   8959.0    10.538759      0.425727  HMDB00254
# 1088   8966.0   8987.0    10.536846      0.122360  HMDB00254
# 1089   8994.0   8996.0    10.363151      0.013080  HMDB00254
# 1090   8996.0  10020.0    18.058010      6.131900  HMDB00254
# 1091      1.0  15512.0   254.316668    100.000000  HMDB00254
# 1092  11899.0  15512.0    19.190284     23.912216  HMDB00254

# %%
features.shape
# Out:
# (1104, 12)
